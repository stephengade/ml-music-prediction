# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import tree
import joblib



file_path = "F:\\DataSets\\music.csv\\music.csv"
music_data = pd.read_csv(file_path)

# initialize the algorithm
model = DecisionTreeClassifier()



# Allocate 20% of the data for testing and the rest for training

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)


# train the model/algorithm by feeding it with input and output
model.fit(X_train, y_train)

# predict
result = model.predict(X_test)

# measure the accuracy

score = accuracy_score(y_test, result)

score
# Out:
# 1.0

# %%
# Save as file and load the model

# // recomender
model_to_save = model.fit(X, y)

# Use joblib passing the model and name you want to save it
joblib.dump(result, "music-recommender.joblib")

# load saved recommender
model = joblib.load("music-recommender.joblib")
predictions =  model.predict([[21,0]])
predictions

# %%
# Save the model visualizer 

# the input which is dropped
X = music_data.drop(columns=['genre'])

# the output
y = music_data['genre']

# // train all data
model.fit(X, y)

# exporting model

tree.export_graphviz(model, 
                     out_file='music-recommender.dot', 
                     feature_names=['age', 'gender'], 
                     class_names=sorted(y.unique()), 
                     label='all', 
                     rounded=True, 
                     filled=True)

# %%
# display the date in graph

import matplotlib.pyplot as plt

# Count the occurrences of each genre
genre_counts = music_data['genre'].value_counts()

# Create a bar chart to visualize the genre distribution
plt.figure(figsize=(8, 6))
genre_counts.plot(kind='bar', color='black')
plt.title('Genre Distribution')
plt.xlabel('Genre')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
